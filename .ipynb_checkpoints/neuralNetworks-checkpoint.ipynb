# %%
# Importing Required Libraries
import os
import librosa
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense
from keras.models import Sequential

# %%
def extract_feature(file_name):
    try:
        audio_data, sample_rate = librosa.load(file_name, res_type='kaiser_fast')
        mfccs = librosa.feature.mfcc(y=audio_data, sr=sample_rate, n_mfcc=40)
        mfccs_processed = np.mean(mfccs.T, axis=0)
        return mfccs_processed
    except Exception as e:
        print(f"Error encountered while parsing file: {file_name}")
        print(e)
        return None

# %%
if __name__ == '__main__':
    # Define the path to the dataset
    data_path = "C:/Users/ADMIN/Downloads/Data/genres_original"

    # Define the number of MFCCs to extract
    num_mfcc = 40

    # Define the number of audio files to read per genre
    num_files_per_genre = 100

    # Define the list of genres to use
    genres = ["blues", "classical", "country", "disco", "hiphop", "jazz", "metal", "pop", "reggae", "rock"]

    # Initialize empty arrays to store features and labels
    features = None
    labels = None

    # Loop through each genre
    for genre in genres:
        # Define the path to the genre folder
        genre_path = os.path.join(data_path, genre)

        # Loop through the first N audio files in the genre folder
        for i, file_name in enumerate(os.listdir(genre_path)[:num_files_per_genre]):
            # Construct the full path to the audio file
            file_path = os.path.join(genre_path, file_name)

            # Extract the MFCCs for the audio file
            mfccs = extract_feature(file_path)

            # If the MFCCs were successfully extracted, add them to the feature matrix and label vector
            if mfccs is not None:
                if features is None:
                    features = mfccs.reshape(1, -1)
                    labels = np.array([genre])
                else:
                    features = np.vstack([features, mfccs.reshape(1, -1)])
                    labels = np.append(labels, genre)

    # Encoding Labels to Integers
    le = LabelEncoder()
    labels = le.fit_transform(labels)

    # Splitting data into training and testing
    X_train, X_test, y_train, y_test = train_test_split(features, labels, test_size=0.2)

    # Initialize the neural network model
    model = Sequential()

    # Add layers to the model
    model.add(Dense(units=128, activation='relu', input_shape=(num_mfcc,)))
    model.add(Dense(units=64, activation='relu'))
    model.add(Dense(units=32, activation='relu'))
    model.add(Dense(units=len(genres), activation='softmax'))
    
    # Compiling the Model
    model.compile(
        optimizer='adam',
        loss='sparse_categorical_crossentropy',
        metrics=['accuracy']
    )

    # Training the Model on the Training Data
    model.fit(
        X_train, y_train,
        validation_data=(X_test, y_test),
        batch_size=32,
        epochs=100
    )

    # Evaluating the Model on the Testing Data
    loss, accuracy = model.evaluate(X_test, y_test)
    print("Accuracy:", accuracy)
# Out:
# Epoch 1/100
# 25/25 [==============================] - 1s 9ms/step - loss: 5.0144 - accuracy: 0.1963 - val_loss: 2.4844 - val_accuracy: 0.2450
# Epoch 2/100
# 25/25 [==============================] - 0s 3ms/step - loss: 2.1455 - accuracy: 0.3025 - val_loss: 1.9588 - val_accuracy: 0.3200
# Epoch 3/100
# 25/25 [==============================] - 0s 3ms/step - loss: 1.6757 - accuracy: 0.4087 - val_loss: 1.6661 - val_accuracy: 0.3750
# Epoch 4/100
# 25/25 [==============================] - 0s 3ms/step - loss: 1.5243 - accuracy: 0.4725 - val_loss: 1.5631 - val_accuracy: 0.4950
# Epoch 5/100
# 25/25 [==============================] - 0s 3ms/step - loss: 1.3955 - accuracy: 0.5025 - val_loss: 1.5006 - val_accuracy: 0.4850
# Epoch 6/100
# 25/25 [==============================] - 0s 3ms/step - loss: 1.2857 - accuracy: 0.5462 - val_loss: 1.5778 - val_accuracy: 0.4750
# Epoch 7/100
# 25/25 [==============================] - 0s 3ms/step - loss: 1.3108 - accuracy: 0.5300 - val_loss: 1.5596 - val_accuracy: 0.4950
# Epoch 8/100
# 25/25 [==============================] - 0s 3ms/step - loss: 1.1988 - accuracy: 0.5562 - val_loss: 1.4073 - val_accuracy: 0.5100
# Epoch 9/100
# 25/25 [==============================] - 0s 3ms/step - loss: 1.1027 - accuracy: 0.6125 - val_loss: 1.3418 - val_accuracy: 0.5500
# Epoch 10/100
# 25/25 [==============================] - 0s 3ms/step - loss: 1.0068 - accuracy: 0.6475 - val_loss: 1.3734 - val_accuracy: 0.5650
# Epoch 11/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.9773 - accuracy: 0.6775 - val_loss: 1.3438 - val_accuracy: 0.5900
# Epoch 12/100
# 25/25 [==============================] - 0s 4ms/step - loss: 0.9196 - accuracy: 0.6862 - val_loss: 1.2970 - val_accuracy: 0.6100
# Epoch 13/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.9391 - accuracy: 0.6837 - val_loss: 1.2988 - val_accuracy: 0.5950
# Epoch 14/100
# 25/25 [==============================] - 0s 4ms/step - loss: 0.8991 - accuracy: 0.6913 - val_loss: 1.3298 - val_accuracy: 0.5700
# Epoch 15/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.
100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.1735 - accuracy: 0.9675 - val_loss: 1.7024 - val_accuracy: 0.6300
# Epoch 51/100
# 25/25 [==============================] - 0s 4ms/step - loss: 0.1757 - accuracy: 0.9525 - val_loss: 1.7878 - val_accuracy: 0.6450
# Epoch 52/100
# 25/25 [==============================] - 0s 4ms/step - loss: 0.1546 - accuracy: 0.9625 - val_loss: 1.7662 - val_accuracy: 0.6450
# Epoch 53/100
# 25/25 [==============================] - 0s 4ms/step - loss: 0.1335 - accuracy: 0.9712 - val_loss: 1.9084 - val_accuracy: 0.6100
# Epoch 54/100
# 25/25 [==============================] - 0s 4ms/step - loss: 0.1334 - accuracy: 0.9688 - val_loss: 1.8501 - val_accuracy: 0.6250
# Epoch 55/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.1039 - accuracy: 0.9850 - val_loss: 1.8511 - val_accuracy: 0.6450
# Epoch 56/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.1075 - accuracy: 0.9837 - val_loss: 1.9110 - val_accuracy: 0.6300
# Epoch 57/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.1125 - accuracy: 0.9775 - val_loss: 1.9755 - val_accuracy: 0.6150
# Epoch 58/100
# 25/25 [==============================] - 0s 4ms/step - loss: 0.1013 - accuracy: 0.9825 - val_loss: 1.9486 - val_accuracy: 0.6200
# Epoch 59/100
# 25/25 [==============================] - 0s 4ms/step - loss: 0.1128 - accuracy: 0.9775 - val_loss: 2.1241 - val_accuracy: 0.6350
# Epoch 60/100
# 25/25 [==============================] - 0s 4ms/step - loss: 0.1184 - accuracy: 0.9750 - val_loss: 2.0076 - val_accuracy: 0.6150
# Epoch 61/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0911 - accuracy: 0.9800 - val_loss: 2.0142 - val_accuracy: 0.6200
# Epoch 62/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0958 - accuracy: 0.9762 - val_loss: 2.0303 - val_accuracy: 0.6150
# Epoch 63/100
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0763 - accuracy: 0.9875 - val_loss: 1.9876 - val_accuracy: 0.6450
# Epoch 64/100
# 25/25 [==============================] - 0s 5ms/step - loss: 0.0792 - accuracy: 0.9887 - val_loss: 1.9373 - val_accuracy: 0.6400
# Epoch 65/100
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0863 - accuracy: 0.9862 - val_loss: 2.1440 - val_accuracy: 0.6150
# Epoch 66/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0884 - accuracy: 0.9812 - val_loss: 2.0553 - val_accuracy: 0.6150
# Epoch 67/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0750 - accuracy: 0.9887 - val_loss: 2.1730 - val_accuracy: 0.6300
# Epoch 68/100
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0668 - accuracy: 0.9887 - val_loss: 2.0778 - val_accuracy: 0.6350
# Epoch 69/100
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0751 - accuracy: 0.9887 - val_loss: 2.1221 - val_accuracy: 0.6150
# Epoch 70/100
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0537 - accuracy: 0.9937 - val_loss: 2.0917 - val_accuracy: 0.6400
# Epoch 71/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0475 - accuracy: 0.9925 - val_loss: 2.1166 - val_accuracy: 0.6500
# Epoch 72/100
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0571 - accuracy: 0.9925 - val_loss: 2.1463 - val_accuracy: 0.6400
# Epoch 73/100
# 25/25 [==============================] - 0s 5ms/step - loss: 0.0492 - accuracy: 0.9950 - val_loss: 2.2721 - val_accuracy: 0.6200
# Epoch 74/100
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0533 - accuracy: 0.9937 - val_loss: 2.2166 - val_accuracy: 0.6200
# Epoch 75/100
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0413 - accuracy: 0.9950 - val_loss: 2.2495 - val_accuracy: 0.6200
# Epoch 76/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0369 - accuracy: 0.9975 - val_loss: 2.2975 - val_accuracy: 0.5950
# Epoch 77/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0377 - accuracy: 0.9950 - val_loss: 2.2353 - val_accuracy: 0.6250
# Epoch 78/100
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0319 - accuracy: 0.9962 - val_loss: 2.2848 - val_accuracy: 0.6200
# Epoch 79/100
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0419 - accuracy: 0.9950 - val_loss: 2.3732 - val_accuracy: 0.6250
# Epoch 80/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0367 - accuracy: 0.9937 - val_loss: 2.3556 - val_accuracy: 0.6150
# Epoch 81/100
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0361 - accuracy: 0.9937 - val_loss: 2.3778 - val_accuracy: 0.6150
# Epoch 82/100
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0365 - accuracy: 0.9950 - val_loss: 2.5107 - val_accuracy: 0.6100
# Epoch 83/100
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0391 - accuracy: 0.9950 - val_loss: 2.4572 - val_accuracy: 0.6050
# Epoch 84/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0373 - accuracy: 0.9975 - val_loss: 2.4132 - val_accuracy: 0.6200
# Epoch 85/100
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0371 - accuracy: 0.9937 - val_loss: 2.4645 - val_accuracy: 0.6400
# Epoch 86/100
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0420 - accuracy: 0.9937 - val_loss: 2.5372 - val_accuracy: 0.6000
# Epoch 87/100
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0367 - accuracy: 0.9950 - val_loss: 2.4460 - val_accuracy: 0.6400
# Epoch 88/100
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0268 - accuracy: 0.9987 - val_loss: 2.4765 - val_accuracy: 0.6100
# Epoch 89/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0307 - accuracy: 0.9950 - val_loss: 2.5668 - val_accuracy: 0.6250
# Epoch 90/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0244 - accuracy: 0.9975 - val_loss: 2.5092 - val_accuracy: 0.6050
# Epoch 91/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0379 - accuracy: 0.9937 - val_loss: 2.6141 - val_accuracy: 0.6050
# Epoch 92/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0404 - accuracy: 0.9925 - val_loss: 2.6558 - val_accuracy: 0.6150
# Epoch 93/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0915 - accuracy: 0.9700 - val_loss: 2.5926 - val_accuracy: 0.6200
# Epoch 94/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.1698 - accuracy: 0.9475 - val_loss: 3.0734 - val_accuracy: 0.5500
# Epoch 95/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.2251 - accuracy: 0.9262 - val_loss: 2.4172 - val_accuracy: 0.6050
# Epoch 96/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.1732 - accuracy: 0.9488 - val_loss: 2.5284 - val_accuracy: 0.5800
# Epoch 97/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.1310 - accuracy: 0.9513 - val_loss: 2.8128 - val_accuracy: 0.5900
# Epoch 98/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.1276 - accuracy: 0.9550 - val_loss: 2.5417 - val_accuracy: 0.5800
# Epoch 99/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0742 - accuracy: 0.9800 - val_loss: 2.6057 - val_accuracy: 0.6200
# Epoch 100/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0354 - accuracy: 0.9950 - val_loss: 2.6113 - val_accuracy: 0.6250
# 7/7 [==============================] - 0s 2ms/step - loss: 2.6113 - accuracy: 0.6250
# Accuracy: 0.625

# %%
# Save the trained model
model.save('my_model.h5')

# Load the saved model
loaded_model = keras.models.load_model('my_model.h5')

# Predict the genre of an audio file
mfccs = extract_feature('C:/Users/ADMIN/Downloads/Data/audio_file.wav')

input_data = mfccs.reshape(1, -1)
# print(input_data)
predicted_genre = loaded_model.predict(input_data)

# Extract genre name from probabilities
genres = ["blues", "classical", "country", "disco", "hiphop", "jazz", "metal", "pop", "reggae", "rock"]
predicted_genre_index = np.argmax(predicted_genre)
predicted_genre_name = genres[predicted_genre_index]
print('Predicted genre: ', predicted_genre_name)
# Out:
# 1/1 [==============================] - 0s 69ms/step
# Predicted genre:  rock

# %%
from sklearn.metrics import confusion_matrix
loaded_model = keras.models.load_model('my_model.h5')
# Get the predicted and actual labels
predicted_labels = np.argmax(loaded_model.predict(X_test), axis=1)
actual_labels = np.argmax(y_test, axis=1)

# Create the confusion matrix
confusion_matrix_vals = confusion_matrix(actual_labels, predicted_labels)

# Print the confusion matrix
print(confusion_matrix_vals)
# Out:
# 7/7 [==============================] - 0s 1ms/step
# ---------------------------------------------------------------------------
# AxisError                                 Traceback (most recent call last)
# Cell In[6], line 5
#       3 # Get the predicted and actual labels
#       4 predicted_labels = np.argmax(loaded_model.predict(X_test), axis=1)
# ----> 5 actual_labels = np.argmax(y_test, axis=1)
#       7 # Create the confusion matrix
#       8 confusion_matrix_vals = confusion_matrix(actual_labels, predicted_labels)
#
# File <__array_function__ internals>:180, in argmax(*args, **kwargs)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\numpy\core\fromnumeric.py:1216, in argmax(a, axis, out, keepdims)
#    1129 """
#    1130 Returns the indices of the maximum values along an axis.
#    1131
#    (...)
#    1213 (2, 1, 4)
#    1214 """
#    1215 kwds = {'keepdims': keepdims} if keepdims is not np._NoValue else {}
# -> 1216 return _wrapfunc(a, 'argmax', axis=axis, out=out, **kwds)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\numpy\core\fromnumeric.py:57, in _wrapfunc(obj, method, *args, **kwds)
#      54     return _wrapit(obj, method, *args, **kwds)
#      56 try:
# ---> 57     return bound(*args, **kwds)
#      58 except TypeError:
#      59     # A TypeError occurs if the object does have such a method in its
#      60     # class, but its signature is not identical to that of NumPy's. This
#    (...)
#      64     # Call _wrapit from within the except clause to ensure a potential
#      65     # exception has a traceback chain.
#      66     return _wrapit(obj, method, *args, **kwds)
#
# AxisError: axis 1 is out of bounds for array of dimension 1
